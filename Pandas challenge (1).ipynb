# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Curtis Wright\Desktop\HW GT ATL\pandas-challenge\purchase_data.csv")

# %%
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
Total_players_df=pd.DataFrame({"Total Players": [df["SN"].nunique()]})
Total_players_df
# Out:
#    Total Players
# 0            576

# %%
Summary_df=pd.DataFrame({"Number of Unique Items": [df["Item ID"].nunique()], "Average Price": [df["Price"].mean()], "Number of Purchases": [df["Purchase ID"].max()],  "Total Revenue": [df["Price"].sum()]})
Summary_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  779        2379.77

# %%
Gender_demographics_df=pd.DataFrame({"Total Count": [df["Gender"].str.count("Male").sum(), df["Gender"].str.count("Female").sum(), df["Gender"].str.count("Other / Non-Disclosed").sum()], "Percentage": [(df["Gender"].str.count("Male").sum()/779), (df["Gender"].str.count("Female").sum()/779), (df["Gender"].str.count("Other / Non-Disclosed").sum()/779)]})

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
Gender_demographics_df
# Out:
#    Total Count  Percentage
# 0          652    0.836970
# 1          113    0.145058
# 2           15    0.019255

# %%
other=df["Gender"].str.count("Other / Non-Disclosed").sum()
other
# Out:
# 15

# %%
gender_df=df.groupby("Gender")
gender_count=gender_df["SN"].nunique()
avg_purchase_price=gender_df["Price"].mean()
total_price=gender_df["Price"].sum()
#avg_total=(gender_df["Price"].sum())/gender_df.count
num_purchases_per_person=gender_df["SN"].nunique()
num_purchases_per_person
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: SN, dtype: int64

# %%
gender_analysis=pd.DataFrame({"Purchase Count": gender_count, "Average Purchase Price": avg_purchase_price,"Total Purchase Value": total_price, "Avg Total Purchase per Person": (total_price/num_purchases_per_person)})

# %%
gender_analysis
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                             81                3.203009
# Male                              484                3.017853
# Other / Non-Disclosed              11                3.346000
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Gender
# Female                               361.94                       4.468395
# Male                                1967.64                       4.065372
# Other / Non-Disclosed                 50.19                       4.562727

# %%
print(df["Age"].min())
df["Age"].max()
# Out:
# 7
# 45

# %%
bins=[7, 12, 17, 22, 27, 32, 37, 42, 47]
group_names=["7 to 12", "12 to 17", "17 to 22", "22 to 27", "27 to 32", "32 to 37", "37 to 42", "42 to 47"]
df["Age Summary"]=pd.cut(df["Age"], bins, labels=group_names)

# %%
age_df=df.groupby(["Age Summary"])

# %%
age_df.count()
# Out:
#              Purchase ID   SN  Age  Gender  Item ID  Item Name  Price
# Age Summary
# 7 to 12               36   36   36      36       36         36     36
# 12 to 17              93   93   93      93       93         93     93
# 17 to 22             280  280  280     280      280        280    280
# 22 to 27             217  217  217     217      217        217    217
# 27 to 32              68   68   68      68       68         68     68
# 32 to 37              49   49   49      49       49         49     49
# 37 to 42              24   24   24      24       24         24     24
# 42 to 47               4    4    4       4        4          4      4

# %%
total_count=age_df["Age"].count()
total_count
# Out:
# Age Summary
# 7 to 12      36
# 12 to 17     93
# 17 to 22    280
# 22 to 27    217
# 27 to 32     68
# 32 to 37     49
# 37 to 42     24
# 42 to 47      4
# Name: Age, dtype: int64

# %%
percentage_count=(total_count)/(total_count.sum())

# %%
Age_df=pd.DataFrame({"Total Count": total_count, "Proportion of Players": total_count/(sum(Age_df["Total Count"]))})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-06fcb179fe5f> in <module>
# ----> 1 Age_df=pd.DataFrame({"Total Count": total_count, "Proportion of Players": total_count/(sum(Age_df["Total Count"]))})
#
# NameError: name 'Age_df' is not defined

# %%
Age_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-d303a8984b29> in <module>
# ----> 1 Age_df
#
# NameError: name 'Age_df' is not defined

# %%
Purchase_Count=age_df["Item ID"].count()
Average_Purchase_price=age_df["Price"].mean()
print(Purchase_Count)
print(Average_Purchase_price)

Total_Purchase_Value=age_df["Price"].sum()
print(Total_Purchase_Value)
# Out:
# Age Summary
# 7 to 12      36
# 12 to 17     93
# 17 to 22    280
# 22 to 27    217
# 27 to 32     68
# 32 to 37     49
# 37 to 42     24
# 42 to 47      4
# Name: Item ID, dtype: int64
# Age Summary
# 7 to 12     3.073889
# 12 to 17    2.979032
# 17 to 22    3.050393
# 22 to 27    3.048249
# 27 to 32    2.952059
# 32 to 37    3.002857
# 37 to 42    3.527083
# 42 to 47    2.765000
# Name: Price, dtype: float64
# Age Summary
# 7 to 12     110.66
# 12 to 17    277.05
# 17 to 22    854.11
# 22 to 27    661.47
# 27 to 32    200.74
# 32 to 37    147.14
# 37 to 42     84.65
# 42 to 47     11.06
# Name: Price, dtype: float64

# %%
Purchasing_analysis_Age=pd.DataFrame({"Purchase Count" : Purchase_Count, "Average Purchase Price": Average_Purchase_price, "Total Purchase Value": Total_Purchase_Value, "Avg Total Purchase per Person": (Total_Purchase_Value)/(age_df["SN"].nunique())})

# %%
Purchasing_analysis_Age
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Summary
# 7 to 12                  36                3.073889                110.66
# 12 to 17                 93                2.979032                277.05
# 17 to 22                280                3.050393                854.11
# 22 to 27                217                3.048249                661.47
# 27 to 32                 68                2.952059                200.74
# 32 to 37                 49                3.002857                147.14
# 37 to 42                 24                3.527083                 84.65
# 42 to 47                  4                2.765000                 11.06
#
#              Avg Total Purchase per Person
# Age Summary
# 7 to 12                           4.098519
# 12 to 17                          3.743919
# 17 to 22                          4.292010
# 22 to 27                          4.134187
# 27 to 32                          4.014800
# ...

# %%
client_name_df=df.set_index("SN")

# %%
client_name_df.loc[["Lisosia93", "Idastidru52", "Chamjask73", "Iral74", "Iskadarya95"]]
# Out:
#              Purchase ID  Age  Gender  Item ID  \
# SN
# Lisosia93             74   25    Male       89
# Lisosia93            120   25    Male       24
# Lisosia93            224   25    Male      157
# Lisosia93            603   25    Male      132
# Lisosia93            609   25    Male       40
# Idastidru52          290   24    Male      147
# Idastidru52          490   24    Male      148
# Idastidru52          543   24    Male      121
# Idastidru52          676   24    Male      111
# Chamjask73           222   22  Female      178
# Chamjask73           520   22  Female      109
# Chamjask73           564   22  Female       52
# Iral74               128   21    Male       58
# Iral74               623   21    Male      114
# Iral74               758   21    Male      182
# Iral74               776   21    Male      164
# Iskadarya95          148   20    Male      148
# Iskadarya95          247   20    Male       82
# Iskadarya95          318   20    Male       91
#
# ...

# %%
AvgPP=client_name_df.loc["Lisosia93", "Price"].mean()

# %%
client_name_df=client_name_df.groupby("SN")

# %%
Total_Purchase_Value=client_name_df.sum().loc[["Lisosia93", "Idastidru52", "Chamjask73", "Iral74", "Iskadarya95"]]["Price"]
Average_Purchase_Price=client_name_df.mean().loc[["Lisosia93", "Idastidru52", "Chamjask73", "Iral74", "Iskadarya95"]]["Price"]
Purchase_Count=client_name_df.nunique().loc[["Lisosia93", "Idastidru52", "Chamjask73", "Iral74", "Iskadarya95"]]["Item Name"]

# %%
Top_Spenders_df=pd.DataFrame({"Purchase Count": Purchase_Count,"Average Purchase Price" : Average_Purchase_Price,"Total Purchase Value": Total_Purchase_Value})

# %%
Top_Spenders_df
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10

# %%
Top_items=df.groupby(["Item ID", "Item Name"])

# %%
Top_items[["SN", "Price"]].nunique().sort_values("Price", ascending=False)
# Out:
#                                                       SN  Price
# Item ID Item Name
# 92      Final Critic                                  13      2
# 1       Crucifer                                       4      2
# 132     Persuasion                                     9      2
# 30      Stormcaller                                    3      2
# 125     Whistling Mithril Warblade                     2      1
# 118     Ghost Reaver, Longsword of Magic               1      1
# 119     Stormbringer, Dark Blade of Ending Misery      3      1
# 120     Agatha                                         6      1
# 121     Massacre                                       4      1
# 122     Unending Tyranny                               3      1
# 123     Twilight's Carver                              4      1
# 124     Venom Claymore                                 4      1
# 127     Heartseeker, Reaver of Souls                   2      1
# ...

# %%
TopItems_df=pd.DataFrame({"Purchase Count": Top_items["Item Name"].count().sort_values(ascending=False), "Item Price": Top_items["Price"].mean(), "Total Purchase Value": Top_items["Price"].sum()})

# %%
TopItems_df
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 0       Splinter                                                   4
# 1       Crucifer                                                   4
# 2       Verdict                                                    6
# 3       Phantomlight                                               6
# 4       Bloodlord's Fetish                                         5
# 5       Putrid Fan                                                 4
# 6       Rusty Skull                                                2
# 7       Thorn, Satchel of Dark Souls                               7
# 8       Purgatory, Gem of Regret                                   3
# 9       Thorn, Conqueror of the Corrupted                          4
# 10      Sleepwalker                                                4
# 11      Brimstone                                                  5
# ...

# %%
TopItems_df=TopItems_df.sort_values("Purchase Count", ascending=False)

# %%
TopItems_df
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 75      Brutality Ivory Warmace                                    8
# 103     Singed Scalpel                                             8
# 34      Retribution Axe                                            8
# 37      Shadow Strike, Glory of Ending Hope                        8
# 19      Pursuit, Cudgel of Necromancy                              8
# 60      Wolf                                                       8
# ...

# %%
TopItemsByPurchaseValue=TopItems_df.sort_values("Total Purchase Value", ascending=False)

# %%
TopItemsByPurchaseValue.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 82      Nirvana                                         4.900000
# 145     Fiery Glass Crusader                            4.580000
# 103     Singed Scalpel                                  4.350000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...
